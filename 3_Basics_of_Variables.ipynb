# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Introduction_to_python/blob/main/3_Basics_of_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("My name is aman kumar")
# Out:
# My name is aman kumar

# %%
number=67
print(number)
# Out:
# 67

# %%
weight=678
print(weight)
# Out:
# 678

# %%
x=weight+number
print(x)
# Out:
# 745

# %%
first_name="aman "
last_name="kumar"
name=first_name+last_name
print(name)
answer=first_name+last_name+str(x)## here x is  now string and not an integer ok
print(answer)
# Out:
# aman kumar
# aman kumar745
